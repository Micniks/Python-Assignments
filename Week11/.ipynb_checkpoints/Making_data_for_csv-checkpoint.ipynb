# %%
#1.1
import requests
import random
import numpy as np
import sys

url_names = 'names.txt'

max_cultist_amount = 100
min_score = 0
max_score = 5

response = requests.get(url_names)
full_read = ''
for line in response:
    decoded_line = line.decode("utf-8")
    full_read = full_read + decoded_line

all_cultist_names = full_read.split('\n');
cultist_names = []
if(len(all_cultist_names) <= max_cultist_amount): 
    cultist_names = all_cultist_names
else:
    cultist_names = all_cultist_names[:max_cultist_amount]

    
#1.2
def recruit_cultist(name):
    cultist = {name: {
    'stealth': random.randint(min_score, max_score), 
    'influence': random.randint(min_score, max_score), 
    'endurance': random.randint(min_score, max_score), 
    'lore': random.randint(min_score, max_score), 
    'economic': random.randint(min_score, max_score), 
    'strength': random.randint(min_score, max_score), 
    'insanity': random.randint(min_score, max_score)}}
    return cultist
    
    
#1.3
def make_cult(cultist_names_list):
    cult = {}
    for cultist in cultist_names_list:
        cult.update(recruit_cultist(cultist))
    return cult

cult = make_cult(cultist_names)


#1.4
cult_roles = {
'Priest': {'stealth': -1, 'influence': 3, 'endurance': 2, 'lore': 4, 'economic': 1, 'strength': 0, 'insanity': 5},
'Enforcer': {'stealth': 1, 'influence': 3, 'endurance': 4, 'lore': 0, 'economic': -1, 'strength': 5, 'insanity': 2},
'Assassin': {'stealth': 5, 'influence': -1, 'endurance': 4, 'lore': 1, 'economic': 0, 'strength': 2, 'insanity': 3},
'Recruiter': {'stealth': 1, 'influence': 5, 'endurance': 0, 'lore': 3, 'economic': 2, 'strength': -1, 'insanity': 4},
'Accountant': {'stealth': 2, 'influence': 1, 'endurance': 3, 'lore': 4, 'economic': 5, 'strength': 0, 'insanity': -1},
'Advisor': {'stealth': 2, 'influence': 4, 'endurance': -1, 'lore': 5, 'economic': 3, 'strength': 0, 'insanity': 1}
}


#Support Method for 1.5
def make_cultist_matrix(data):
    stats = ['stealth', 'influence', 'endurance', 'lore', 'economic', 'strength', 'insanity']
    matrix = []
    names = []
    for name, stats_values in data.items():
        matrix.append(list(stats_values[key] for key in stats))
        names.append(name)
    return {'names': names,'matrix': np.array(matrix)}


#1.5
def assign_cult_roles(cult, cult_roles):
    matrix_cultists_info = make_cultist_matrix(cult)
    cultists_names = matrix_cultists_info['names']
    matrix_C = matrix_cultists_info['matrix']
    matrix_roles_info = make_cultist_matrix(cult_roles)
    roles_names = matrix_roles_info['names']
    matrix_R = matrix_roles_info['matrix'].T
    result_values = matrix_C.dot(matrix_R)
    
    #print('Cultist Values:\n', matrix_C, end='\n\n')
    #print('Roles Modificers:\n', matrix_R, end='\n\n')
    #print('Cultist Role Results:\n', result_values, end='\n\n')
    
    result = {}
    for y_idx in range(0, len(result_values)-1):
        name = cultists_names[y_idx]
        row = result_values[y_idx]
        highest= {'idx': 0, 'value': -sys.maxsize - 1, 'role': ''}
        for x_idx in range(0,len(row)):
            if(highest['value'] < row[x_idx]):
                highest['idx'] = x_idx
                highest['value'] = row[x_idx]
                highest['role'] = roles_names[x_idx]
        result.update({name: highest['role']})
    return result

def print_role_amount(cultists_roles):
    amounts_for_roles = {}
    for role in cult_roles:
        amounts_for_roles.update({role: 0})
    for cultist in cultists_roles:
        role = cultists_roles[cultist]
        amounts_for_roles[role] += 1
    for role in amounts_for_roles:
        print(role + ':', amounts_for_roles[role])

culists_roles = assign_cult_roles(cult, cult_roles)
#print(culists_roles)
print_role_amount(culists_roles)
print()

for cultist in cult:
    print(cultist, cult[cultist])
# Out:
# Priest: 15
# Enforcer: 22
# Assassin: 22
# Recruiter: 7
# Accountant: 21
# Advisor: 12
#
# Johnathon Compton {'stealth': 4, 'influence': 2, 'endurance': 5, 'lore': 2, 'economic': 4, 'strength': 3, 'insanity': 2}
# Wilma Hudson {'stealth': 5, 'influence': 3, 'endurance': 5, 'lore': 5, 'economic': 5, 'strength': 4, 'insanity': 3}
# Mary Harrington {'stealth': 5, 'influence': 1, 'endurance': 2, 'lore': 5, 'economic': 5, 'strength': 1, 'insanity': 4}
# Thelma Blanchard {'stealth': 4, 'influence': 2, 'endurance': 1, 'lore': 2, 'economic': 0, 'strength': 2, 'insanity': 1}
# Lindsey Mcgee {'stealth': 4, 'influence': 0, 'endurance': 2, 'lore': 3, 'economic': 2, 'strength': 5, 'insanity': 0}
# Harlan Ewing {'stealth': 3, 'influence': 2, 'endurance': 5, 'lore': 5, 'economic': 1, 'strength': 1, 'insanity': 0}
# Cara Giles {'stealth': 3, 'influence': 0, 'endurance': 2, 'lore': 0, 'economic': 1, 'strength': 5, 'insanity': 5}
# Roger Oliver {'stealth': 2, 'influence': 1, 'endurance': 4, 'lore': 1, 'economic': 5, 'strength': 0, 'insanity': 3}
# Herminia Munoz {'stealth': 0, 'influence': 4, 'endurance': 5, 'lore': 1, 'economic': 1, 'strength': 2, 'insanity': 0}
# Fred Alvarez {'stealth': 3, 'influence': 5, 'endurance': 3, 'lore': 4, 'economic': 2, 'strength': 5, 'insanity': 2}
# Bud Woods {'stealth': 5, 'influence': 2, 'endurance': 2, 'lore': 5, 'economic': 0, 'strength': 4, 'insanity': 4}
# Freida Case {'stealth': 0, 'influence': 5, 'endurance': 1, 'lore': 3, 'economic': 4, 'strength': 4, 'insanity': 3}
# Eldridge Hatfield {'stealth': 3, 'influence': 2, 'endurance': 5, 'lore': 2, 'economic': 0, 'strength': 0, 'insanity': 0}
# Jan Cabrera {'stealth': 4, 'influence': 4, 'endurance': 0, 'lore': 1, 'economic': 3, 'strength': 3, 'insanity': 4}
# Jermaine Pratt {'stealth': 1, 'influence': 4, 'endurance': 3, 'lore': 2, 'economic': 5, 'strength': 4, 'insanity': 0}
# Lanny Huynh {'stealth': 4, 'influence': 4, 'endurance': 4, 'lore': 1, 'economic': 1, 'strength': 0, 'insanity': 2}
# Ulysses Mccall {'stealth': 0, 'influence': 2, 'endurance': 0, 'lore': 4, 'economic': 5, 'strength': 5, 'insanity': 4}
# Coleen Weber {'stealth': 0, 'influence': 0, 'endurance': 0, 'lore': 3, 'economic': 1, 'strength': 2, 'insanity': 5}
# Trudy Gaines {'stealth': 3, 'influence': 4, 'endurance': 2, 'lore': 1, 'economic': 3, 'strength': 2, 'insanity': 0}
# Loyd Tapia {'stealth': 4, 'influence': 5, 'endurance': 4, 'lore': 0, 'economic': 1, 'strength': 1, 'insanity': 3}
# George Gordon {'stealth': 2, 'influence': 2, 'endurance': 0, 'lore': 1, 'economic': 1, 'strength': 3, 'insanity': 0}
# Nick Oconnor {'stealth': 2, 'influence': 5, 'endurance': 5, 'lore': 4, 'economic': 0, 'strength': 1, 'insanity': 2}
# Latoya Gilmore {'stealth': 4, 'influence': 5, 'endurance': 1, 'lore': 4, 'economic': 5, 'strength': 4, 'insanity': 3}
# Eldon Pena {'stealth': 0, 'influence': 5, 'endurance': 3, 'lore': 1, 'economic': 5, 'strength': 1, 'insanity': 4}
# Tania Roberson {'stealth': 0, 'influence': 4, 'endurance': 4, 'lore': 0, 'economic': 5, 'strength': 1, 'insanity': 5}
# Allie Sanchez {'stealth': 0, 'influence': 1, 'endurance': 1, 'lore': 4, 'economic': 2, 'strength': 3, 'insanity': 0}
# Weston Chang {'stealth': 2, 'influence': 2, 'endurance': 3, 'lore': 0, 'economic': 0, 'strength': 1, 'insanity': 0}
# Marci Salinas {'stealth': 1, 'influence': 1, 'endurance': 1, 'lore': 3, 'economic': 0, 'strength': 0, 'insanity': 5}
# Tasha Allison {'stealth': 5, 'influence': 1, 'endurance': 0, 'lore': 2, 'economic': 3, 'strength': 4, 'insanity': 3}
# Jerri Carey {'stealth': 2, 'influence': 2, 'endurance': 5, 'lore': 1, 'economic': 2, 'strength': 2, 'insanity': 5}
# Virginia Harrison {'stealth': 3, 'influence': 1, 'endurance': 1, 'lore': 1, 'economic': 4, 'strength': 4, 'insanity': 4}
# April Hull {'stealth': 3, 'influence': 4, 'endurance': 0, 'lore': 4, 'economic': 5, 'strength': 3, 'insanity': 4}
# Lupe Eaton {'stealth': 0, 'influence': 2, 'endurance': 4, 'lore': 2, 'economic': 3, 'strength': 0, 'insanity': 5}
# Inez Lozano {'stealth': 0, 'influence': 5, 'endurance': 0, 'lore': 3, 'economic': 5, 'strength': 5, 'insanity': 0}
# Forrest Santana {'stealth': 3, 'influence': 0, 'endurance': 1, 'lore': 4, 'economic': 2, 'strength': 1, 'insanity': 0}
# Deloris Frank {'stealth': 4, 'influence': 4, 'endurance': 2, 'lore': 5, 'economic': 4, 'strength': 0, 'insanity': 3}
# Olivia Hendrix {'stealth': 4, 'influence': 5, 'endurance': 0, 'lore': 4, 'economic': 0, 'strength': 0, 'insanity': 1}
# Granville Cannon {'stealth': 2, 'influence': 4, 'endurance': 1, 'lore': 4, 'economic': 1, 'strength': 5, 'insanity': 3}
# Jefferey Weeks {'stealth': 3, 'influence': 0, 'endurance': 5, 'lore': 4, 'economic': 1, 'strength': 5, 'insanity': 3}
# Noble Buck {'stealth': 0, 'influence': 2, 'endurance': 3, 'lore': 5, 'economic': 2, 'strength': 0, 'insanity': 0}
# Gracie Benitez {'stealth': 2, 'influence': 4, 'endurance': 2, 'lore': 5, 'economic': 0, 'strength': 5, 'insanity': 2}
# Levi Peterson {'stealth': 3, 'influence': 1, 'endurance': 2, 'lore': 2, 'economic': 5, 'strength': 2, 'insanity': 0}
# Reginald Odom {'stealth': 3, 'influence': 5, 'endurance': 3, 'lore': 5, 'economic': 3, 'strength': 0, 'insanity': 4}
# Brain Wiley {'stealth': 5, 'influence': 5, 'endurance': 2, 'lore': 3, 'economic': 2, 'strength': 5, 'insanity': 2}
# Mari Stanton {'stealth': 3, 'influence': 3, 'endurance': 0, 'lore': 0, 'economic': 4, 'strength': 1, 'insanity': 1}
# Marcella Barrett {'stealth': 3, 'influence': 4, 'endurance': 2, 'lore': 1, 'economic': 0, 'strength': 2, 'insanity': 3}
# Cecile Herrera {'stealth': 2, 'influence': 4, 'endurance': 5, 'lore': 1, 'economic': 5, 'strength': 3, 'insanity': 2}
# Marty Tucker {'stealth': 5, 'influence': 5, 'endurance': 4, 'lore': 3, 'economic': 2, 'strength': 5, 'insanity': 0}
# Sharron Werner {'stealth': 0, 'influence': 0, 'endurance': 0, 'lore': 5, 'economic': 2, 'strength': 2, 'insanity': 4}
# Fredric James {'stealth': 5, 'influence': 2, 'endurance': 2, 'lore': 1, 'economic': 2, 'strength': 1, 'insanity': 5}
# Kerry Myers {'stealth': 5, 'influence': 0, 'endurance': 5, 'lore': 3, 'economic': 1, 'strength': 5, 'insanity': 2}
# Herminia Pineda {'stealth': 4, 'influence': 4, 'endurance': 3, 'lore': 1, 'economic': 3, 'strength': 4, 'insanity': 4}
# Elnora Johnston {'stealth': 1, 'influence': 3, 'endurance': 1, 'lore': 2, 'economic': 5, 'strength': 1, 'insanity': 5}
# Sonja Maddox {'stealth': 5, 'influence': 1, 'endurance': 1, 'lore': 0, 'economic': 1, 'strength': 5, 'insanity': 1}
# Irwin Schwartz {'stealth': 5, 'influence': 3, 'endurance': 3, 'lore': 4, 'economic': 2, 'strength': 5, 'insanity': 1}
# Jame Stark {'stealth': 2, 'influence': 5, 'endurance': 2, 'lore': 0, 'economic': 0, 'strength': 2, 'insanity': 0}
# Katelyn Maxwell {'stealth': 2, 'influence': 2, 'endurance': 5, 'lore': 0, 'economic': 0, 'strength': 1, 'insanity': 1}
# Janine Haas {'stealth': 0, 'influence': 1, 'endurance': 1, 'lore': 1, 'economic': 4, 'strength': 3, 'insanity': 3}
# Heather Morales {'stealth': 2, 'influence': 4, 'endurance': 3, 'lore': 0, 'economic': 2, 'strength': 5, 'insanity': 2}
# Garret Shaffer {'stealth': 1, 'influence': 3, 'endurance': 2, 'lore': 3, 'economic': 1, 'strength': 5, 'insanity': 5}
# Jillian Salas {'stealth': 3, 'influence': 1, 'endurance': 2, 'lore': 4, 'economic': 4, 'strength': 2, 'insanity': 2}
# Rachel Rosario {'stealth': 5, 'influence': 3, 'endurance': 0, 'lore': 2, 'economic': 5, 'strength': 4, 'insanity': 0}
# Morgan Anderson {'stealth': 5, 'influence': 3, 'endurance': 1, 'lore': 0, 'economic': 0, 'strength': 4, 'insanity': 1}
# Carlos Chapman {'stealth': 4, 'influence': 5, 'endurance': 5, 'lore': 4, 'economic': 5, 'strength': 0, 'insanity': 2}
# Earnestine Dickson {'stealth': 0, 'influence': 2, 'endurance': 5, 'lore': 2, 'economic': 4, 'strength': 1, 'insanity': 5}
# Arline Brock {'stealth': 4, 'influence': 0, 'endurance': 0, 'lore': 1, 'economic': 0, 'strength': 3, 'insanity': 3}
# Roger Neal {'stealth': 1, 'influence': 5, 'endurance': 2, 'lore': 5, 'economic': 0, 'strength': 4, 'insanity': 0}
# Merle Gonzales {'stealth': 0, 'influence': 5, 'endurance': 0, 'lore': 1, 'economic': 0, 'strength': 3, 'insanity': 3}
# Lindsay Callahan {'stealth': 4, 'influence': 1, 'endurance': 4, 'lore': 2, 'economic': 4, 'strength': 5, 'insanity': 2}
# Frieda Pham {'stealth': 1, 'influence': 3, 'endurance': 3, 'lore': 3, 'economic': 4, 'strength': 2, 'insanity': 4}
# Lorene Reeves {'stealth': 0, 'influence': 1, 'endurance': 0, 'lore': 1, 'economic': 4, 'strength': 4, 'insanity': 1}
# Saul Baldwin {'stealth': 3, 'influence': 1, 'endurance': 1, 'lore': 2, 'economic': 5, 'strength': 1, 'insanity': 1}
# Darryl Graves {'stealth': 4, 'influence': 0, 'endurance': 3, 'lore': 0, 'economic': 0, 'strength': 2, 'insanity': 3}
# Michael Bartlett {'stealth': 4, 'influence': 3, 'endurance': 4, 'lore': 5, 'economic': 3, 'strength': 5, 'insanity': 5}
# Terence Pitts {'stealth': 0, 'influence': 0, 'endurance': 1, 'lore': 5, 'economic': 3, 'strength': 0, 'insanity': 3}
# Aimee Hammond {'stealth': 5, 'influence': 3, 'endurance': 5, 'lore': 4, 'economic': 0, 'strength': 0, 'insanity': 3}
# Basil Flynn {'stealth': 4, 'influence': 0, 'endurance': 2, 'lore': 3, 'economic': 2, 'strength': 1, 'insanity': 1}
# Celia Roman {'stealth': 1, 'influence': 3, 'endurance': 4, 'lore': 3, 'economic': 4, 'strength': 0, 'insanity': 3}
# Damien Donovan {'stealth': 3, 'influence': 0, 'endurance': 2, 'lore': 4, 'economic': 5, 'strength': 4, 'insanity': 1}
# Carter Lam {'stealth': 4, 'influence': 3, 'endurance': 0, 'lore': 5, 'economic': 5, 'strength': 5, 'insanity': 5}
# Lucile Hart {'stealth': 4, 'influence': 4, 'endurance': 4, 'lore': 1, 'economic': 5, 'strength': 3, 'insanity': 2}
# Sara Stanley {'stealth': 5, 'influence': 5, 'endurance': 1, 'lore': 2, 'economic': 2, 'strength': 4, 'insanity': 1}
# Nick King {'stealth': 4, 'influence': 5, 'endurance': 4, 'lore': 1, 'economic': 4, 'strength': 5, 'insanity': 0}
# Martina Daniel {'stealth': 1, 'influence': 4, 'endurance': 2, 'lore': 3, 'economic': 1, 'strength': 1, 'insanity': 3}
# Neva Bruce {'stealth': 2, 'influence': 0, 'endurance': 4, 'lore': 2, 'economic': 2, 'strength': 1, 'insanity': 1}
# Long Brooks {'stealth': 4, 'influence': 4, 'endurance': 5, 'lore': 3, 'economic': 0, 'strength': 1, 'insanity': 2}
# Alexandra Drake {'stealth': 5, 'influence': 5, 'endurance': 1, 'lore': 0, 'economic': 0, 'strength': 4, 'insanity': 3}
# Erick Page {'stealth': 3, 'influence': 1, 'endurance': 5, 'lore': 1, 'economic': 3, 'strength': 0, 'insanity': 1}
# Lora Dalton {'stealth': 1, 'influence': 4, 'endurance': 2, 'lore': 4, 'economic': 1, 'strength': 5, 'insanity': 3}
# Eloise Hurley {'stealth': 3, 'influence': 3, 'endurance': 5, 'lore': 5, 'economic': 3, 'strength': 5, 'insanity': 5}
# Lenny Serrano {'stealth': 1, 'influence': 4, 'endurance': 3, 'lore': 3, 'economic': 3, 'strength': 5, 'insanity': 3}
# Ken Lynn {'stealth': 0, 'influence': 2, 'endurance': 3, 'lore': 5, 'economic': 2, 'strength': 3, 'insanity': 5}
# Camille Pace {'stealth': 5, 'influence': 3, 'endurance': 4, 'lore': 5, 'economic': 5, 'strength': 4, 'insanity': 2}
# Alyce Ortiz {'stealth': 3, 'influence': 5, 'endurance': 5, 'lore': 3, 'economic': 3, 'strength': 0, 'insanity': 4}
# Carol Potter {'stealth': 1, 'influence': 4, 'endurance': 3, 'lore': 0, 'economic': 5, 'strength': 1, 'insanity': 0}
# Grady Booker {'stealth': 4, 'influence': 0, 'endurance': 3, 'lore': 5, 'economic': 1, 'strength': 0, 'insanity': 1}
# Jewell Bender {'stealth': 0, 'influence': 3, 'endurance': 4, 'lore': 2, 'economic': 3, 'strength': 5, 'insanity': 2}
# Everette Burgess {'stealth': 1, 'influence': 4, 'endurance': 0, 'lore': 3, 'economic': 1, 'strength': 0, 'insanity': 1}
# Marshall Day {'stealth': 3, 'influence': 5, 'endurance': 2, 'lore': 5, 'economic': 4, 'strength': 2, 'insanity': 0}
# Pasquale Rios {'stealth': 5, 'influence': 4, 'endurance': 1, 'lore': 3, 'economic': 4, 'strength': 5, 'insanity': 5}

# %% [markdown]
# ## Class exercise
# 1. Traverse and print each node plus sequence number of the node in the traversal of the below graph
# 2. Create a function that can take a name and show all employees that are in the  to that supervisor. E.g Helge has Charlie and Hanne, Charlie has Jannie and Else.

# %%
graph = {
  'Helge' : ['Charlie','Hanne'],
  'Charlie' : ['Jannie', 'Else'],
  'Hanne' : ['Frederik', 'Ayse'],
  'Jannie' : [],
  'Else' : [],
  'Frederik' : [],
  'Ayse' : ['Holger'],
  'Holger' : ['Hans'],
  'Hans' : []
}

visited = []   # List to keep track of visited nodes.
queue = []     # Initialize a queue

def bfs(visited, graph, node):
    visited.append(node)
    queue.append(node)

    while queue: # while the list is not empty
        s = queue.pop(0) 
        print(str(visited.index(s)) + ': ' + s) # end = (default is \n)

        for neighbour in graph[s]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)

                
def bfs_two(visited, graph, node):
    visited.append(node)
    queue.append(node)
    
    while queue:
        s = queue.pop(0) 
              
        count = 0
        for neighbour in graph[s]:
            
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)
                if count == 0 and count == len(graph[s])-1:
                    print(s + ' has', end = " ")
                    print(neighbour)
                elif count == 0:
                    print(s + ' has', end = " ")
                    print(neighbour, end = '')
                elif (count != len(graph[s])-1):
                    print(', ' + neighbour, end = '')
                else:
                    print(' and ' + neighbour)
                count+=1
        
            

# Driver Code
bfs_two(visited, graph, 'Helge')
# Out:
# Helge has Charlie and Hanne
# Charlie has Jannie and Else
# Hanne has Frederik and Ayse
# Ayse has Holger
# Holger has Hans

# %% [markdown]
# My own testing:

# %%
required_room_conn = 3
required_start_room_conn = 2
min_rooms = required_room_conn
max_rooms = 10

def find_minimum():
    graph = {}
    print('Room Amount should start as: ' + str(min_rooms))
    for amount in range(min_rooms, max_rooms+1):
        room_number = 1;
        for room in range(0,amount):
            if(room_number == 1):
                graph[room_number] = [0.0];
            else:
                graph[room_number] = [0,0,0];
            room_number+=1;
        print('Room Amount: ' + str(len(graph)))
    
        result = check_combinations(graph)
        if(result):
            print(result)
            break
            
    
    
def check_combinations(graph):
    possible_combinations = []
    room_range = len(graph)
    for room in graph:
        for connections in graph[room]:
            possible_combinations.append(connections)
            
    looping = True;
    all_combinations = []
    while(looping):
        possible_combinations[0] += 1
        for idx in range(0,len(possible_combinations)):
            if(possible_combinations[idx] > room_range):
                if(idx < len(possible_combinations)-1):
                    possible_combinations[idx] = 0
                    possible_combinations[idx+1] += 1
                else:
                    looping = False
        all_combinations.append(possible_combinations.copy())
        com = possible_combinations.copy()
        first_room_good = com[0] != 0 and com[1] != 0 and com[0] != 1 and com[1] != 1 and com[0] != com[1]
        room = [2,3,4]
        room_num = 2
        other_rooms_good = True
        while(room[2] < len(possible_combinations)-1):
            setdir = {}
            for conn in room:
                if(com[conn] != 0 and com[conn] != room_num):
                    other_rooms_good = False
                else:
                    setdir[com[conn]] = ''
            if (len(setdir) != 3):
                other_rooms_good = False
            for idx in range(0,len(room)):
                room[idx] += 3
            room_num += 1
            
        if(first_room_good and other_rooms_good):
            return possible_combinations
                
    print(len(all_combinations))
    return False

def bfs(visited, graph, node):
    visited.append(node)
    queue.append(node)

    while queue: # while the list is not empty
        s = queue.pop(0) 
        print(str(visited.index(s)) + ': ' + s) # end = (default is \n)

        for neighbour in graph[s]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)
                
find_minimum()
# Out:
# Room Amount should start as: 3
# Room Amount: 3
# 16384
# Room Amount: 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-2d9fd44b9a30> in <module>
#      80                 queue.append(neighbour)
#      81
# ---> 82 find_minimum()
#
# <ipython-input-34-2d9fd44b9a30> in find_minimum()
#      17         print('Room Amount: ' + str(len(graph)))
#      18
# ---> 19         result = check_combinations(graph)
#      20         if(result):
#      21             print(result)
#
# <ipython-input-34-2d9fd44b9a30> in check_combinations(graph)
#      43                     looping = False
#      44         all_combinations.append(possible_combinations.copy())
# ---> 45         com = possible_combinations.copy()
#      46         first_room_good = com[0] != 0 and com[1] != 0 and com[0] != 1 and com[1] != 1 and com[0] != com[1]
#      47         room = [2,3,4]
#
# ...
